# %%
import sys
sys.path.append("..")  # o el path a tu carpeta 'backend'

# %%
from app.procesos import process
from datetime import date

# %%
inicio = date(2025,3,1)
fin = date(2025,3,10)

# %%
pedidos = process.armar_seguimiento(inicio,fin)

# %%
from pandas import json_normalize

# %%
df = json_normalize(pedidos)

# %%
df[df['pedido'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [pedido, cliente, razonsocial, sucursal, fecha_pedido, fecha_administracion, zona, NombreVendedor, facturas, remitos, Total_PedCliCab, importe_factura, canped1, canped2, canent1, canent2, fecha_procesado, fecha_finalizado, entrega_estado, entrega_fecha_estado, entrega_motivo, entrega_fecha_update, entrega_historial]
# Index: []

# %%
pedidos
# Out:
# [{'pedido': '200010436',
#   'cliente': 'SAUER IGNA',
#   'razonsocial': 'SAUER IGNACIO JOSE',
#   'sucursal': 'SAUER IGNACIO',
#   'fecha_pedido': '2025-03-01',
#   'fecha_administracion': None,
#   'zona': 'SUR',
#   'NombreVendedor': 'Jorge Lopez',
#   'facturas': '13358',
#   'remitos': '1755',
#   'Total_PedCliCab': '48009796.62',
#   'importe_factura': '47344675.46',
#   'canped1': 5484,
#   'canped2': 939,
#   'canent1': 5334,
#   'canent2': 924,
#   'fecha_procesado': None,
#   'fecha_finalizado': '2025-03-19 23:37:14',
#   'entrega_estado': 'ENTREGADO',
#   'entrega_fecha_estado': '2025-03-19 00:00:00',
#   'entrega_motivo': None,
#   'entrega_fecha_update': '2025-03-20',
#   'entrega_historial': []},
#  {'pedido': '200010437',
#   'cliente': 'VERCELLI',
#   'razonsocial': 'JUAN VERCELLI',
#   'sucursal': 'RETIRA CLIENTE',
#   'fecha_pedido': '2025-03-01',
#   'fecha_administracion': None,
#   'zona': 'RETIRA',
#   'NombreVendedor': 'Jorge Lopez',
#   'facturas': '13336',
# ...
